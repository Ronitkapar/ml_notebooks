# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No          NaN     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No          NaN   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
df.tail()
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 77294  77294  qp0d4n   49       2:0  0.067203  Residential              1
# 77295  77295  qp0d4q   49       2:0  0.022859  Residential              3
# 77296  77296  qp0d4w   49       2:0  0.141342  Residential              3
# 77297  77297  qp0dhw   49       2:0  0.087574  Residential              1
# 77298  77298  qp0djq   49       2:0  0.002944  Residential              3
#
#       LargeVehicles Landmarks  Temperature Weather
# 77294   Not Allowed        No    11.501664   Rainy
# 77295       Allowed       Yes    14.715254   Foggy
# 77296       Allowed       Yes    19.678860   Sunny
# 77297   Not Allowed        No    22.573958   Sunny
# 77298       Allowed       Yes     1.322034   Snowy

# %%
df_test.head()
# Out:
#    Index geohash  day timestamp     RoadType  NumberofLanes LargeVehicles  \
# 0      0  qp02z1   49      2:15          NaN              1   Not Allowed
# 1      1  qp02z9   49      2:15  Residential              1   Not Allowed
# 2      2  qp02yf   49      2:15  Residential              3       Allowed
# 3      3  qp02z6   49      2:15  Residential              2   Not Allowed
# 4      4  qp02zd   49      2:15  Residential              1   Not Allowed
#
#   Landmarks  Temperature Weather
# 0        No          NaN     NaN
# 1        No     6.476213   Snowy
# 2       Yes    22.318203   Sunny
# 3       Yes          NaN   Rainy
# 4        No    18.266162   Foggy

# %%
df.shape
# Out:
# (77299, 11)

# %%
df.describe()
# Out:
#               Index           day        demand  NumberofLanes   Temperature
# count  77299.000000  77299.000000  7.729900e+04   77299.000000  74804.000000
# mean   38649.000000     48.101838  9.394238e-02       2.014334     16.405354
# std    22314.443566      0.302438  1.421905e-01       0.904665      7.359835
# min        0.000000     48.000000  6.245650e-07       1.000000    -14.935097
# 25%    19324.500000     48.000000  1.822723e-02       1.000000     11.430473
# 50%    38649.000000     48.000000  4.775994e-02       2.000000     16.382587
# 75%    57973.500000     48.000000  1.085951e-01       3.000000     21.298833
# max    77298.000000     49.000000  1.000000e+00       5.000000     48.251433

# %%
df.isnull().sum()
# Out:
# Index               0
# geohash             0
# day                 0
# timestamp           0
# demand              0
# RoadType          600
# NumberofLanes       0
# LargeVehicles       0
# Landmarks           0
# Temperature      2495
# Weather           797
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77299 entries, 0 to 77298
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          77299 non-null  int64
#  1   geohash        77299 non-null  str
#  2   day            77299 non-null  int64
#  3   timestamp      77299 non-null  str
#  4   demand         77299 non-null  float64
#  5   RoadType       76699 non-null  str
#  6   NumberofLanes  77299 non-null  int64
#  7   LargeVehicles  77299 non-null  str
#  8   Landmarks      77299 non-null  str
#  9   Temperature    74804 non-null  float64
#  10  Weather        76502 non-null  str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 6.5 MB

# %% [markdown]
# ## Null values: RoadType    Tempreature      Weather

# %%
df.head()
# Out:
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No          NaN     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No          NaN   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
print(df['timestamp'].nunique())
df['timestamp'].value_counts()
# Out:
# 96
# timestamp
# 2:0      1778
# 1:45     1755
# 1:30     1750
# 1:15     1698
# 1:0      1668
#          ...
# 19:30     308
# 18:30     303
# 18:45     297
# 19:0      292
# 19:15     288
# Name: count, Length: 96, dtype: int64

# %%
df['demand'].nunique()
# Out:
# 76715

# %%
print(f"unique values in 'Weather' column: {df['Weather'].nunique()}")
print(f"NULL values in 'Weather' column: {df['Weather'].isnull().sum()}")
# Out:
# unique values in 'Weather' column: 4
# NULL values in 'Weather' column: 797

# %%
print(f"unique values in 'Temperature' column: {df['Temperature'].nunique()}")
print(f"NULL values in 'Temperature' column: {df['Temperature'].isnull().sum()}")
# Out:
# unique values in 'Temperature' column: 74804
# NULL values in 'Temperature' column: 2495

# %%
print(f"unique values in 'Landmarks' column: {df['Landmarks'].nunique()}")
print(f"unique values COUNT in 'Landmarks' column: {df['Landmarks'].value_counts()}")
# Out:
# unique values in 'Landmarks' column: 2
# unique values COUNT in 'Landmarks' column: Landmarks
# Yes    52042
# No     25257
# Name: count, dtype: int64

# %%
print(f"unique values in 'LargeVehicles' column: {df['LargeVehicles'].nunique()}")
print(f"unique values COUNT in 'LargeVehicles' column: {df['LargeVehicles'].value_counts()}")
# Out:
# unique values in 'LargeVehicles' column: 2
# unique values COUNT in 'LargeVehicles' column: LargeVehicles
# Not Allowed    50673
# Allowed        26626
# Name: count, dtype: int64

# %%
print(f"unique values in 'NumberofLanes' column: {df['NumberofLanes'].nunique()}")
print(f"unique values COUNT in 'NumberofLanes' column: {df['NumberofLanes'].value_counts()}")
# Out:
# unique values in 'NumberofLanes' column: 5
# unique values COUNT in 'NumberofLanes' column: NumberofLanes
# 1    27411
# 2    24127
# 3    23919
# 4      926
# 5      916
# Name: count, dtype: int64

# %%
print(f"Unique values in 'RoadType' column: {df['RoadType'].nunique()}")
print(f"Unique values COUNT in 'RoadType' column: {df['RoadType'].value_counts()}")
print(f"Null values in RoadType column: {df['RoadType'].isnull().sum()}")
# Out:
# Unique values in 'RoadType' column: 3
# Unique values COUNT in 'RoadType' column: RoadType
# Residential    69230
# Street          3909
# Highway         3560
# Name: count, dtype: int64
# Null values in RoadType column: 600

# %% [markdown]
# # Demand is the Target

# %%
print(f"Unique values in 'day column': {df['day'].nunique()}")
# Out:
# Unique values in 'day column': 2

# %%
print(f"Unique values in geohash column: {df['geohash'].nunique()}")
#print(f"Count of unique Values in geohash column: \n {df['geohash'].value_counts()}")
# Out:
# Unique values in geohash column: 1249

# %%
df.head()
# Out:
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No          NaN     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No          NaN   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
#X= df.drop(['demand'],axis=1)
#Y = df['demand']

# %%
col = df.columns
print(col)
# Out:
# Index(['Index', 'geohash', 'day', 'timestamp', 'demand', 'RoadType',
#        'NumberofLanes', 'LargeVehicles', 'Landmarks', 'Temperature',
#        'Weather'],
#       dtype='str')

# %%
def ColumnAnalysis(dataframe):

    columns = dataframe.columns

    for col in columns:

        bold_col = f"\033[1m{col}\033[0m"  #creating helper variable!

        print(f"Data type of {bold_col} column: {dataframe[col].dtype}")
        print(f"Unique values in '{bold_col}' column: {dataframe[col].nunique()}")

        if dataframe[col].value_counts().shape[0] < 25:
            print(f"count of unique values in {bold_col} column: \n{dataframe[col].value_counts()}")
        else:
            print(f"Count of unique values in {bold_col} column is more than 25, so not displaying the count.")
        print(f"sample values in {bold_col} column: \n{dataframe[col].sample(10)}")

        print('\n')
        print("="*90)

# %%
ColumnAnalysis(df)
# Out:
# Data type of Index column: int64
# Unique values in 'Index' column: 77299
# Count of unique values in Index column is more than 25, so not displaying the count.
# sample values in Index column:
# 68207    68207
# 6863      6863
# 70559    70559
# 1076      1076
# 68708    68708
# 8593      8593
# 3748      3748
# 37437    37437
# 43611    43611
# 42746    42746
# Name: Index, dtype: int64
#
#
# ==========================================================================================
# Data type of geohash column: str
# Unique values in 'geohash' column: 1249
# Count of unique values in geohash column is more than 25, so not displaying the count.
# sample values in geohash column:
# 23148    qp03xz
# 24204    qp09uv
# 23323    qp09vn
# 69396    qp0d4s
# 62162    qp03yv
# 18369    qp03w8
# 54420    qp03zh
# 12708    qp093c
# 25294    qp02zy
# 61165    qp03pp
# Name: geohash, dtype: str
#
#
# ==========================================================================================
# Data type of day column: int64
# Unique values in 'day' column: 2
# count of unique values in day column:
# day
# 48    69427
# 49     7872
# Name: count, dtype: int64
# sample values in day column:
# 45437    48
# 57961    48
# 3625     48
# 62372    48
# 56329    48
# 25687    48
# 26984    48
# 67719    48
# 7374     48
# 14335    48
# Name: day, dtype: int64
#
#
# ==========================================================================================
# Data type of timestamp column: str
# Unique values in 'timestamp' column: 96
# Count of unique values in timestamp column is more than 25, so not displaying the count.
# sample values in timestamp column:
# 46666    13:15
# 70410     0:15
# 65728    22:45
# 26924     7:30
# 4073      1:15
# 37195    10:30
# 9874       3:0
# 43405    12:15
# 19379     5:30
# 77155      2:0
# Name: timestamp, dtype: str
#
#
# ==========================================================================================
# Data type of demand column: float64
# Unique values in 'demand' column: 76715
# Count of unique values in demand column is more than 25, so not displaying the count.
# sample values in demand column:
# 75169    0.035895
# 60477    0.009024
# 22780    0.003716
# 34668    0.072791
# 11412    0.068018
# 39343    0.000919
# 66334    0.006255
# 77076    0.105474
# 17181    0.010183
# 24498    0.046646
# Name: demand, dtype: float64
#
#
# ==========================================================================================
# Data type of RoadType column: str
# Unique values in 'RoadType' column: 3
# count of unique values in RoadType column:
# RoadType
# Residential    69230
# Street          3909
# Highway         3560
# Name: count, dtype: int64
# sample values in RoadType column:
# 13516    Residential
# 12856    Residential
# 2235     Residential
# 13154    Residential
# 44329    Residential
# 39514    Residential
# 74858    Residential
# 65305    Residential
# 5644     Residential
# 15548    Residential
# Name: RoadType, dtype: str
#
#
# ==========================================================================================
# Data type of NumberofLanes column: int64
# Unique values in 'NumberofLanes' column: 5
# count of unique values in NumberofLanes column:
# NumberofLanes
# 1    27411
# 2    24127
# 3    23919
# 4      926
# 5      916
# Name: count, dtype: int64
# sample values in NumberofLanes column:
# 45197    1
# 27281    2
# 22253    2
# 50298    2
# 62677    1
# 45029    2
# 18967    1
# 50308    1
# 45527    1
# 17562    1
# Name: NumberofLanes, dtype: int64
#
#
# ==========================================================================================
# Data type of LargeVehicles column: str
# Unique values in 'LargeVehicles' column: 2
# count of unique values in LargeVehicles column:
# LargeVehicles
# Not Allowed    50673
# Allowed        26626
# Name: count, dtype: int64
# sample values in LargeVehicles column:
# 57543        Allowed
# 36486    Not Allowed
# 56590        Allowed
# 51911        Allowed
# 49359    Not Allowed
# 20284    Not Allowed
# 18975    Not Allowed
# 48586    Not Allowed
# 49975    Not Allowed
# 35159        Allowed
# Name: LargeVehicles, dtype: str
#
#
# ==========================================================================================
# Data type of Landmarks column: str
# Unique values in 'Landmarks' column: 2
# count of unique values in Landmarks column:
# Landmarks
# Yes    52042
# No     25257
# Name: count, dtype: int64
# sample values in Landmarks column:
# 34943     No
# 44172    Yes
# 62287    Yes
# 39373     No
# 26644    Yes
# 34321    Yes
# 50734     No
# 64273     No
# 53657    Yes
# 3206     Yes
# Name: Landmarks, dtype: str
#
#
# ==========================================================================================
# Data type of Temperature column: float64
# Unique values in 'Temperature' column: 74804
# Count of unique values in Temperature column is more than 25, so not displaying the count.
# sample values in Temperature column:
# 2425     19.789490
# 40544    19.238378
# 19991     2.035907
# 19996    36.875937
# 39535     9.176144
# 21522    19.954080
# 37524    32.688764
# 17275    23.483838
# 49803    15.303928
# 40081    24.667240
# Name: Temperature, dtype: float64
#
#
# ==========================================================================================
# Data type of Weather column: str
# Unique values in 'Weather' column: 4
# count of unique values in Weather column:
# Weather
# Sunny    27717
# Rainy    20824
# Foggy    20243
# Snowy     7718
# Name: count, dtype: int64
# sample values in Weather column:
# 28557    Sunny
# 18603    Sunny
# 44360    Foggy
# 60671    Foggy
# 2166     Foggy
# 41658    Foggy
# 6236     Sunny
# 47976    Foggy
# 62805    Sunny
# 4000     Rainy
# Name: Weather, dtype: str
#
#
# ==========================================================================================

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['demand'], kde=True)
plt.show()

# %%
df['demand'].skew()
# Out:
# np.float64(3.7285172887316627)

# %%
df['demand'].describe()
# Out:
# count    7.729900e+04
# mean     9.394238e-02
# std      1.421905e-01
# min      6.245650e-07
# 25%      1.822723e-02
# 50%      4.775994e-02
# 75%      1.085951e-01
# max      1.000000e+00
# Name: demand, dtype: float64

# %%
(df['demand'] == 1).sum()
# Out:
# np.int64(585)

# %%
df['demand'].value_counts().head(20)
# Out:
# demand
# 1.000000    585
# 0.048804      1
# 0.118507      1
# 0.027132      1
# 0.003272      1
# 0.010819      1
# 0.016262      1
# 0.042247      1
# 0.040135      1
# 0.001002      1
# 0.003948      1
# 0.017780      1
# 0.089060      1
# 0.050096      1
# 0.152598      1
# 0.011870      1
# 0.005091      1
# 0.001492      1
# 0.003284      1
# 0.001297      1
# Name: count, dtype: int64

# %%
df['day'].dtype
# Out:
# dtype('int64')

# %%
col = df.columns
col
# Out:
# Index(['Index', 'geohash', 'day', 'timestamp', 'demand', 'RoadType',
#        'NumberofLanes', 'LargeVehicles', 'Landmarks', 'Temperature',
#        'Weather'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Index               0
# geohash             0
# day                 0
# timestamp           0
# demand              0
# RoadType          600
# NumberofLanes       0
# LargeVehicles       0
# Landmarks           0
# Temperature      2495
# Weather           797
# dtype: int64

# %%
len(df['RoadType'])
# Out:
# 77299

# %%
df['RoadType'].isnull().sum()
# Out:
# np.int64(600)

# %%
print(f"{df['RoadType'].isnull().sum()/len(df['RoadType'])*100:.2f}%")
# Out:
# 0.78%

# %%
def NullAnalysis(dataframe):

    null_percentages = (dataframe.isnull().sum() / len(dataframe)) * 100

    null_percentages = (
        null_percentages[null_percentages > 0]
        .sort_values(ascending=False)
    )

    if len(null_percentages) == 0:
        print("No missing values found.")
        return

    print("Columns with missing values:\n")

    for col, pct in null_percentages.items():
        print(f"{col}: {pct:.2f}%")

# %%
NullAnalysis(df)
# Out:
# Columns with missing values:
#
# Temperature: 3.23%
# Weather: 1.03%
# RoadType: 0.78%

# %%
def NullAnalysis(dataframe):

    null_percentages = (dataframe.isnull().sum() / len(dataframe)) * 100

    null_percentages = null_percentages[
        null_percentages > 0
    ].sort_values(ascending=False)

    for col, pct in null_percentages.items():
        print(f"{col}: {pct:.2f}%")

# %%
NullAnalysis(df)
# Out:
# Temperature: 3.23%
# Weather: 1.03%
# RoadType: 0.78%

# %%
null_percentages = (df.isnull().sum() / len(df)) * 100
print(null_percentages)
# Out:
# Index            0.000000
# geohash          0.000000
# day              0.000000
# timestamp        0.000000
# demand           0.000000
# RoadType         0.776207
# NumberofLanes    0.000000
# LargeVehicles    0.000000
# Landmarks        0.000000
# Temperature      3.227726
# Weather          1.031061
# dtype: float64

# %%
df['Temperature']=df['Temperature'].fillna(df['Temperature'].median(), inplace = True)

sns.histplot(
    df["Temperature"],
    kde=True
)
# Out:
# /tmp/ipykernel_1171512/3733789265.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Temperature']=df['Temperature'].fillna(df['Temperature'].median(), inplace = True)
# <Axes: xlabel='Temperature', ylabel='Count'>

# %%
# 1.2: Type of column
## for each column, will be checking its dtype, no. of unique values.

def ColumnAnalysis(dataframe):

    columns = dataframe.columns

    for col in columns:

        bold_col = f"\033[1m{col}\033[0m"  #creating helper variable!

        print(f"Data type of {bold_col} column: {dataframe[col].dtype}")
        print(f"Unique values in '{bold_col}' column: {dataframe[col].nunique()}")

        if dataframe[col].value_counts().shape[0] < 25:
            counts = dataframe[col].value_counts()
            summary = pd.DataFrame({
                'Value' : counts,
                'Percentage (%)' :  (counts/len(dataframe)*100).round(2)
            })
            print(summary)

        else:
            print(f"Count of unique values in {bold_col} column is more than 25, so not displaying the count.")
        print(f"sample values in {bold_col} column: \n{dataframe[col].sample(10)}")

        print('\n')
        print("="*90)

# %%
ColumnAnalysis(df)
# Out:
# Data type of Index column: int64
# Unique values in 'Index' column: 77299
# Count of unique values in Index column is more than 25, so not displaying the count.
# sample values in Index column:
# 63661    63661
# 49489    49489
# 39950    39950
# 69132    69132
# 17159    17159
# 65759    65759
# 36948    36948
# 61240    61240
# 29177    29177
# 51530    51530
# Name: Index, dtype: int64
#
#
# ==========================================================================================
# Data type of geohash column: str
# Unique values in 'geohash' column: 1249
# Count of unique values in geohash column is more than 25, so not displaying the count.
# sample values in geohash column:
# 68804    qp097f
# 28946    qp095q
# 66823    qp03xz
# 1204     qp09b0
# 7841     qp03zv
# 77210    qp06p1
# 9839     qp08gx
# 55530    qp09fd
# 2582     qp098k
# 35852    qp06pt
# Name: geohash, dtype: str
#
#
# ==========================================================================================
# Data type of day column: int64
# Unique values in 'day' column: 2
#      Value  Percentage (%)
# day
# 48   69427           89.82
# 49    7872           10.18
# sample values in day column:
# 3472     48
# 18986    48
# 62032    48
# 12995    48
# 9933     48
# 64392    48
# 4875     48
# 73955    49
# 3603     48
# 53790    48
# Name: day, dtype: int64
#
#
# ==========================================================================================
# Data type of timestamp column: str
# Unique values in 'timestamp' column: 96
# Count of unique values in timestamp column is more than 25, so not displaying the count.
# sample values in timestamp column:
# 50034    14:15
# 65501    22:30
# 6916       2:0
# 71149     0:30
# 44250    12:30
# 14324     4:15
# 1689      0:30
# 75486     1:30
# 46247     13:0
# 14499     4:15
# Name: timestamp, dtype: str
#
#
# ==========================================================================================
# Data type of demand column: float64
# Unique values in 'demand' column: 76715
# Count of unique values in demand column is more than 25, so not displaying the count.
# sample values in demand column:
# 31855    0.649337
# 59829    0.035185
# 23949    0.028062
# 30056    0.050976
# 52357    0.009380
# 58605    0.010081
# 77298    0.002944
# 46493    0.017316
# 39514    0.101178
# 24637    0.599472
# Name: demand, dtype: float64
#
#
# ==========================================================================================
# Data type of RoadType column: str
# Unique values in 'RoadType' column: 3
#              Value  Percentage (%)
# RoadType
# Residential  69230           89.56
# Street        3909            5.06
# Highway       3560            4.61
# sample values in RoadType column:
# 60425    Residential
# 69458    Residential
# 11292    Residential
# 21887         Street
# 38601    Residential
# 16514        Highway
# 2810     Residential
# 16150    Residential
# 75748    Residential
# 8539     Residential
# Name: RoadType, dtype: str
#
#
# ==========================================================================================
# Data type of NumberofLanes column: int64
# Unique values in 'NumberofLanes' column: 5
#                Value  Percentage (%)
# NumberofLanes
# 1              27411           35.46
# 2              24127           31.21
# 3              23919           30.94
# 4                926            1.20
# 5                916            1.19
# sample values in NumberofLanes column:
# 30427    1
# 678      3
# 57260    2
# 60377    2
# 29177    1
# 50435    1
# 65187    1
# 32294    1
# 63255    1
# 42809    2
# Name: NumberofLanes, dtype: int64
#
#
# ==========================================================================================
# Data type of LargeVehicles column: str
# Unique values in 'LargeVehicles' column: 2
#                Value  Percentage (%)
# LargeVehicles
# Not Allowed    50673           65.55
# Allowed        26626           34.45
# sample values in LargeVehicles column:
# 70190        Allowed
# 12129        Allowed
# 45709    Not Allowed
# 67916    Not Allowed
# 6550     Not Allowed
# 15341    Not Allowed
# 10329    Not Allowed
# 38836        Allowed
# 60971    Not Allowed
# 1288         Allowed
# Name: LargeVehicles, dtype: str
#
#
# ==========================================================================================
# Data type of Landmarks column: str
# Unique values in 'Landmarks' column: 2
#            Value  Percentage (%)
# Landmarks
# Yes        52042           67.33
# No         25257           32.67
# sample values in Landmarks column:
# 14574     No
# 44465    Yes
# 18454    Yes
# 52960    Yes
# 53417    Yes
# 30924     No
# 38360    Yes
# 19780     No
# 44018    Yes
# 34001    Yes
# Name: Landmarks, dtype: str
#
#
# ==========================================================================================
# Data type of Temperature column: float64
# Unique values in 'Temperature' column: 74805
# Count of unique values in Temperature column is more than 25, so not displaying the count.
# sample values in Temperature column:
# 9022     26.547648
# 2830     -0.354946
# 30443     7.453944
# 74282     1.996625
# 69877     6.408194
# 17065    14.426127
# 45009    27.468070
# 62817    14.927913
# 68461    12.690953
# 4140     18.253345
# Name: Temperature, dtype: float64
#
#
# ==========================================================================================
# Data type of Weather column: str
# Unique values in 'Weather' column: 4
#          Value  Percentage (%)
# Weather
# Sunny    27717           35.86
# Rainy    20824           26.94
# Foggy    20243           26.19
# Snowy     7718            9.98
# sample values in Weather column:
# 69648    Rainy
# 10041    Foggy
# 36333    Sunny
# 68653    Snowy
# 45341    Foggy
# 22421    Sunny
# 56529    Rainy
# 26264    Sunny
# 30883    Foggy
# 67844    Sunny
# Name: Weather, dtype: str
#
#
# ==========================================================================================

# %%
df['demand'].corr(df['Temperature'])
# Out:
# np.float64(0.0030910781711998257)

# %%
df.head()
# Out:
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No    16.382587     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No    16.382587   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
df['timestamp'].sample(10)
# Out:
# 37051    10:30
# 24989      7:0
# 31573      9:0
# 40360    11:15
# 22609     6:30
# 68837    23:45
# 642        0:0
# 40671    11:30
# 73067      1:0
# 30073     8:30
# Name: timestamp, dtype: str

# %%
hrs= df['timestamp'].str.split(':', expand= True).astype(int)

# %%
df.head()
# Out:
#    Index geohash  day    demand     RoadType  NumberofLanes LargeVehicles  \
# 0      0  qp02z1   48  0.048804          NaN              1   Not Allowed
# 1      1  qp02zt   48  0.118507  Residential              3       Allowed
# 2      2  qp08bj   48  0.027132  Residential              1   Not Allowed
# 3      3  qp08gt   48  0.003272  Residential              1   Not Allowed
# 4      4  qp02zq   48  0.010819  Residential              1   Not Allowed
#
#   Landmarks  Temperature Weather  hour  minute
# 0        No    16.382587     NaN     0       0
# 1       Yes    31.104565   Sunny     0       0
# 2        No    25.919267   Sunny     0       0
# 3        No    16.382587   Rainy     0       0
# 4        No    10.803667   Rainy     0       0

# %%
df['hour'].value_counts().sort_index()
# Out:
# hour
# 0     6338
# 1     6871
# 2     4455
# 3     3595
# 4     3683
# 5     3621
# 6     3665
# 7     3569
# 8     3507
# 9     3549
# 10    3622
# 11    3567
# 12    3525
# 13    3271
# 14    3000
# 15    2580
# 16    2108
# 17    1684
# 18    1247
# 19    1214
# 20    1418
# 21    1738
# 22    2410
# 23    3062
# Name: count, dtype: int64

# %%
df['hour'].dtype
# Out:
# dtype('int32')

# %%
df['demand'].dtype
# Out:
# dtype('float64')

# %%
df['Landmarks'].value_counts()
# Out:
# Landmarks
# Yes    52042
# No     25257
# Name: count, dtype: int64

# %%
df['LargeVehicles'] = df['LargeVehicles'].map(
    {"Allowed":1,
     "Not Allowed" :0})

df['Landmarks'] = df['Landmarks'].map({
    "Yes":1,
    "No": 0
})

# %%
df.groupby("Weather")["demand"].mean().sort_values(ascending = False)
# Out:
# Weather
# Rainy    0.094471
# Sunny    0.094247
# Foggy    0.093372
# Snowy    0.092581
# Name: demand, dtype: float64

# %%
def categorical_target_analysis(listofcols,target_col,dataframe):

    for col in listofcols:

        print(f"Mean relationship between {col} and {target_col}:\n")
        mean = dataframe.groupby(col)[target_col].mean().sort_values(ascending = False)
        print(mean)
        print(f"\nMedian relationship between {col} and {target_col}:\n")
        median = dataframe.groupby(col)[target_col].median().sort_values(ascending = False)
        print(median)  
        print("="*90)
        print("\n")

# %%
categorical_cols = [
    "Weather",
    "RoadType",
    "LargeVehicles",
    "Landmarks",
    "NumberofLanes",
    "day"
]
categorical_target_analysis(categorical_cols,'demand',df)
# Out:
# Mean relationship between Weather and demand:
#
# Weather
# Rainy    0.094471
# Sunny    0.094247
# Foggy    0.093372
# Snowy    0.092581
# Name: demand, dtype: float64
#
# Median relationship between Weather and demand:
#
# Weather
# Rainy    0.048467
# Snowy    0.047775
# Foggy    0.047571
# Sunny    0.047230
# Name: demand, dtype: float64
# ==========================================================================================
#
#
# Mean relationship between RoadType and demand:
#
# RoadType
# Highway        0.610756
# Street         0.273164
# Residential    0.057209
# Name: demand, dtype: float64
#
# Median relationship between RoadType and demand:
#
# RoadType
# Highway        0.526432
# Street         0.268124
# Residential    0.040517
# Name: demand, dtype: float64
# ==========================================================================================
#
#
# Mean relationship between LargeVehicles and demand:
#
# LargeVehicles
# 1    0.131923
# 0    0.073986
# Name: demand, dtype: float64
#
# Median relationship between LargeVehicles and demand:
#
# LargeVehicles
# 1    0.051223
# 0    0.046023
# Name: demand, dtype: float64
# ==========================================================================================
#
#
# Mean relationship between Landmarks and demand:
#
# Landmarks
# 0    0.096295
# 1    0.092801
# Name: demand, dtype: float64
#
# Median relationship between Landmarks and demand:
#
# Landmarks
# 1    0.048974
# 0    0.045579
# Name: demand, dtype: float64
# ==========================================================================================
#
#
# Mean relationship between NumberofLanes and demand:
#
# NumberofLanes
# 5    0.607556
# 4    0.602882
# 1    0.088104
# 3    0.077859
# 2    0.077488
# Name: demand, dtype: float64
#
# Median relationship between NumberofLanes and demand:
#
# NumberofLanes
# 5    0.521678
# 4    0.513090
# 1    0.052204
# 2    0.043005
# 3    0.042845
# Name: demand, dtype: float64
# ==========================================================================================
#
#
# Mean relationship between day and demand:
#
# day
# 49    0.105262
# 48    0.092659
# Name: demand, dtype: float64
#
# Median relationship between day and demand:
#
# day
# 49    0.055901
# 48    0.046806
# Name: demand, dtype: float64
# ==========================================================================================

# %%
pd.crosstab(df["NumberofLanes"], df["RoadType"])
# Out:
# RoadType       Highway  Residential  Street
# NumberofLanes
# 1                    0        23269    3909
# 2                  855        23091       0
# 3                  881        22870       0
# 4                  915            0       0
# 5                  909            0       0

# %%
df['NumberofLanes'].dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    Index geohash  day    demand     RoadType  NumberofLanes  LargeVehicles  \
# 0      0  qp02z1   48  0.048804          NaN              1              0
# 1      1  qp02zt   48  0.118507  Residential              3              1
# 2      2  qp08bj   48  0.027132  Residential              1              0
# 3      3  qp08gt   48  0.003272  Residential              1              0
# 4      4  qp02zq   48  0.010819  Residential              1              0
#
#    Landmarks  Temperature Weather  hour  minute
# 0          0    16.382587     NaN     0       0
# 1          1    31.104565   Sunny     0       0
# 2          0    25.919267   Sunny     0       0
# 3          0    16.382587   Rainy     0       0
# 4          0    10.803667   Rainy     0       0

# %%
col = ['hour','minute','Temperature']

for c in col:
    x = df[c].corr(df['demand'])
    print(f"{c} : {x}")
# Out:
# hour : -0.03780626655413724
# minute : 0.0007833826388816719
# Temperature : 0.003091078171199826

# %%
df.groupby("hour")["demand"].mean().sort_values(ascending=False)
# Out:
# hour
# 11    0.117301
# 13    0.116308
# 12    0.114770
# 10    0.111602
# 9     0.109231
# 14    0.107166
# 7     0.106198
# 8     0.106149
# 5     0.104368
# 6     0.103913
# 4     0.101678
# 23    0.092517
# 3     0.091329
# 1     0.089793
# 2     0.087368
# 0     0.083369
# 15    0.083161
# 22    0.074544
# 16    0.070065
# 17    0.058905
# 21    0.056955
# 18    0.048787
# 20    0.043778
# 19    0.042114
# Name: demand, dtype: float64

# %%
df.groupby("minute")["demand"].mean().sort_values(ascending=False)
# Out:
# minute
# 15    0.094172
# 45    0.094070
# 30    0.093889
# 0     0.093652
# Name: demand, dtype: float64

# %%
print(pd.qcut(df["Temperature"], q=10))
# Out:
# 0        (14.768, 16.383]
# 1        (25.703, 48.251]
# 2        (25.703, 48.251]
# 3        (14.768, 16.383]
# 4        (10.393, 12.748]
#                ...
# 77294    (10.393, 12.748]
# 77295    (12.748, 14.768]
# 77296      (18.01, 20.05]
# 77297    (22.351, 25.703]
# 77298    (-14.936, 7.103]
# Name: Temperature, Length: 77299, dtype: category
# Categories (10, interval[float64, right]): [(-14.936, 7.103] < (7.103, 10.393] < (10.393, 12.748] < (12.748, 14.768] ... (18.01, 20.05] < (20.05, 22.351] < (22.351, 25.703] < (25.703, 48.251]]

# %%
df.groupby("geohash")["demand"].mean()
# Out:
# geohash
# qp02yc    0.018498
# qp02yf    0.029433
# qp02yy    0.002902
# qp02yz    0.036564
# qp02z1    0.040048
#             ...
# qp0dn4    0.007811
# qp0dn5    0.003714
# qp0dnh    0.001401
# qp0dnj    0.026414
# qp0dnn    0.004244
# Name: demand, Length: 1249, dtype: float64

# %%
hourly_demand = df.groupby("hour")["demand"].mean()

plt.figure(figsize=(10,5))
plt.plot(hourly_demand.index, hourly_demand.values)
plt.xlabel("Hour")
plt.ylabel("Mean Demand")
plt.title("Mean Demand by Hour")

plt.grid(True)
plt.show()

# %%
df["Temperature"].describe()
# Out:
# count    77299.000000
# mean        16.404619
# std          7.240083
# min        -14.935097
# 25%         11.624189
# 50%         16.382587
# 75%         21.115592
# max         48.251433
# Name: Temperature, dtype: float64

# %%
df.groupby(pd.qcut(df["Temperature"], q=10))["demand"].mean().sort_index()
# Out:
# Temperature
# (-14.936, 7.103]    0.092241
# (7.103, 10.393]     0.094841
# (10.393, 12.748]    0.096403
# (12.748, 14.768]    0.091432
# (14.768, 16.383]    0.094001
# (16.383, 18.01]     0.094411
# (18.01, 20.05]      0.092230
# (20.05, 22.351]     0.092675
# (22.351, 25.703]    0.098160
# (25.703, 48.251]    0.093097
# Name: demand, dtype: float64

# %%
df["geohash"].nunique()
# Out:
# 1249

# %%
import sklearn
from sklearn import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop = 'first')

encoded_data = encoder.fit_transform(df[['Weather']])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[105], line 2
#       1 import sklearn
# ----> 2 from sklearn import OneHotEncoder
#       3
#       4 encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop = 'first')
#       5
#
# ImportError: cannot import name 'OneHotEncoder' from 'sklearn' (/home/ronit/anaconda3/envs/py3.12/lib/python3.12/site-packages/sklearn/__init__.py)

# %%
df.head()
# Out:
#    Index geohash  day    demand     RoadType  NumberofLanes  LargeVehicles  \
# 0      0  qp02z1   48  0.048804          NaN              1              0
# 1      1  qp02zt   48  0.118507  Residential              3              1
# 2      2  qp08bj   48  0.027132  Residential              1              0
# 3      3  qp08gt   48  0.003272  Residential              1              0
# 4      4  qp02zq   48  0.010819  Residential              1              0
#
#    Landmarks  Temperature Weather  hour  minute
# 0          0    16.382587     NaN     0       0
# 1          1    31.104565   Sunny     0       0
# 2          0    25.919267   Sunny     0       0
# 3          0    16.382587   Rainy     0       0
# 4          0    10.803667   Rainy     0       0

# %%
df['day'].dtype
# Out:
# dtype('int64')
